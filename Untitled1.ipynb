# %%
import pandas as pd

# %%
category = "repellents-fresheners"
prods = pd.read_csv("/home/poulami/Documents/Github/Internship/Data"+category+".csv")
prods = prods.fillna("")
print(prods.columns)
prods['how to use'] = prods[['howtouse','howtouseemptythecontentsontoatrayorabowlandplaceitanywhereinyourhousedryplace','howtouseplacethediffuseronaflatstablesurfacecarefullyremovetherubbercapoffthesurrounddiffuserandplantthewoodencapplacethereedsticksinthearomaoilthearomanaturallydiffusesintothesurroundingsinvertthereedsticksonalternatedaysforbestresults','howtouseplacethediffuseronaflatstablesurfacepourjasminearomaoilintothepebblediffuserplacesolawoodflowerontopofthepebblediffuserandletitsthreadfallintotheoilabeautifulchangeinthecolouroftheflowerwouldsignalthearomanaturallypermeatingtothesurroundings','howtouses']].apply(lambda x: ''.join(x), axis=1)
#prods['specifications'] = prods[['specificationbranddptypehangermodelnobbpmaterialplasticcolourmulticolorweightgmdimensionxxlxwxhcmnoofpcspc','specificationbrandenweitypehangermodelnobbmaterialplasticcolourmulticoloursweightgmdimensionxxlxwxhcm','specifications']].apply(lambda x: ''.join(x), axis=1)
#prods['careinstructions'] = prods[['careinstruction', 'careinstructions', 'careinstructionsy']].apply(lambda x: ''.join(x), axis=1)
#prods = prods.drop(['careinstruction', 'careinstructions', 'careinstructionsy'],axis=1)
#prods = prods.drop(['brand.1', 'MRP.1'],axis=1)
prods = prods.drop(['Unnamed: 0','howtouse','howtouseemptythecontentsontoatrayorabowlandplaceitanywhereinyourhousedryplace','howtouseplacethediffuseronaflatstablesurfacecarefullyremovetherubbercapoffthesurrounddiffuserandplantthewoodencapplacethereedsticksinthearomaoilthearomanaturallydiffusesintothesurroundingsinvertthereedsticksonalternatedaysforbestresults','howtouseplacethediffuseronaflatstablesurfacepourjasminearomaoilintothepebblediffuserplacesolawoodflowerontopofthepebblediffuserandletitsthreadfallintotheoilabeautifulchangeinthecolouroftheflowerwouldsignalthearomanaturallypermeatingtothesurroundings','howtouses'],axis=1)
prods = prods.drop_duplicates().reset_index(drop=True)
print(prods.shape[0])
print(prods.head())
print(prods.tail())
prods.to_csv("/home/poulami/Documents/Github/Internship/Data/"+category+".csv")
#prods.to_csv("/home/poulami/Documents/Github/Internship/temp.csv")
# Out:
# Index(['Unnamed: 0', 'Unnamed: 1', 'MRP', 'SP', 'about', 'base url',
#        'benefits', 'brand', 'breadcrumbs', 'careinstructions', 'composition',
#        'discount', 'ean', 'features', 'howtouse',
#        'howtouseemptythecontentsontoatrayorabowlandplaceitanywhereinyourhousedryplace',
#        'howtouseplacethediffuseronaflatstablesurfacecarefullyremovetherubbercapoffthesurrounddiffuserandplantthewoodencapplacethereedsticksinthearomaoilthearomanaturallydiffusesintothesurroundingsinvertthereedsticksonalternatedaysforbestresults',
#        'howtouseplacethediffuseronaflatstablesurfacepourjasminearomaoilintothepebblediffuserplacesolawoodflowerontopofthepebblediffuserandletitsthreadfallintotheoilabeautifulchangeinthecolouroftheflowerwouldsignalthearomanaturallypermeatingtothesurroundings',
#        'howtouses', 'ingredients', 'otherproductinfo', 'pc_n', 'product',
#        'sku', 'specifications', 'tlc_n', 'weight'],
#       dtype='object')
# 233
# ...
